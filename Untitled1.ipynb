# %%
# %matplotlib inline
import pandas as pd

df=pd.read_csv("full_data.csv")

# %%
#Check df dimensions

df.shape
# Out:
# (83278, 10)

# %%
#Check head

df.head(10)
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths  \
# 0  2020-02-24  Afghanistan        1.0         NaN          1.0           NaN
# 1  2020-02-25  Afghanistan        0.0         NaN          1.0           NaN
# 2  2020-02-26  Afghanistan        0.0         NaN          1.0           NaN
# 3  2020-02-27  Afghanistan        0.0         NaN          1.0           NaN
# 4  2020-02-28  Afghanistan        0.0         NaN          1.0           NaN
# 5  2020-02-29  Afghanistan        0.0         NaN          1.0           NaN
# 6  2020-03-01  Afghanistan        0.0         NaN          1.0           NaN
# 7  2020-03-02  Afghanistan        0.0         NaN          1.0           NaN
# 8  2020-03-03  Afghanistan        1.0         NaN          2.0           NaN
# 9  2020-03-04  Afghanistan        2.0         NaN          4.0           NaN
#
#    weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# ...

# %%
#Check tail

df.tail(10)
# Out:
#              date  location  new_cases  new_deaths  total_cases  total_deaths  \
# 83268  2021-04-22  Zimbabwe       38.0         0.0      38018.0        1555.0
# 83269  2021-04-23  Zimbabwe       27.0         1.0      38045.0        1556.0
# 83270  2021-04-24  Zimbabwe       19.0         0.0      38064.0        1556.0
# 83271  2021-04-25  Zimbabwe       22.0         1.0      38086.0        1557.0
# 83272  2021-04-26  Zimbabwe       16.0         3.0      38102.0        1560.0
# 83273  2021-04-27  Zimbabwe       62.0         5.0      38164.0        1565.0
# 83274  2021-04-28  Zimbabwe       27.0         0.0      38191.0        1565.0
# 83275  2021-04-29  Zimbabwe       44.0         2.0      38235.0        1567.0
# 83276  2021-04-30  Zimbabwe       22.0         0.0      38257.0        1567.0
# 83277  2021-05-01  Zimbabwe        3.0         1.0      38260.0        1568.0
#
#        weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# ...

# %%
#Check column types

df.dtypes
# Out:
# date                object
# location            object
# new_cases          float64
# new_deaths         float64
# total_cases        float64
# total_deaths       float64
# weekly_cases       float64
# weekly_deaths      float64
# biweekly_cases     float64
# biweekly_deaths    float64
# dtype: object

# %%
#Deep dive specific column

type(df['date'][0])
# Out:
# str

# %%
#Check unique values

df.nunique()
# Out:
# date                 466
# location             199
# new_cases          11639
# new_deaths          2744
# total_cases        45123
# total_deaths       17191
# weekly_cases       22210
# weekly_deaths       6187
# biweekly_cases     27325
# biweekly_deaths     7942
# dtype: int64

# %%
#Check for duplis

sum(df.duplicated())
# Out:
# 0

# %%
#Check for NaN

df.info()

df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83278 entries, 0 to 83277
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             83278 non-null  object
#  1   location         83278 non-null  object
#  2   new_cases        83269 non-null  float64
#  3   new_deaths       73757 non-null  float64
#  4   total_cases      83271 non-null  float64
#  5   total_deaths     73599 non-null  float64
#  6   weekly_cases     82268 non-null  float64
#  7   weekly_deaths    82268 non-null  float64
#  8   biweekly_cases   80875 non-null  float64
#  9   biweekly_deaths  80875 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 6.4+ MB
# date                  0
# location              0
# new_cases             9
# new_deaths         9521
# total_cases           7
# total_deaths       9679
# weekly_cases       1010
# weekly_deaths      1010
# biweekly_cases     2403
# ...

# %%
df.groupby(by=["location"]).sum()
# Out:
#                new_cases  new_deaths   total_cases  total_deaths  \
# location
# Afghanistan      59939.0      2631.0  1.523703e+07      592183.0
# Africa         4565548.0    122068.0  7.601800e+08    19186992.0
# Albania         131185.0      2396.0  1.607552e+07      307985.0
# Algeria         122311.0      3261.0  2.417390e+07      740111.0
# Andorra          13232.0       125.0  2.001700e+06       28544.0
# ...                  ...         ...           ...           ...
# Vietnam           2942.0        35.0  4.937140e+05        9143.0
# World        151372377.0   3192566.0  2.170926e+10   529642430.0
# Yemen             6325.0      1229.0  7.786870e+05      201614.0
# Zambia           91670.0      1251.0  1.089980e+07      170641.0
# Zimbabwe         38260.0      1568.0  5.404837e+06      192947.0
#
#              weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# location
# Afghanistan  4.157080e+05        18257.0    8.232170e+05          36146.0
# ...

# %%
df.groupby(by="location").sum()
# Out:
#                new_cases  new_deaths   total_cases  total_deaths  \
# location
# Afghanistan      59939.0      2631.0  1.523703e+07      592183.0
# Africa         4565548.0    122068.0  7.601800e+08    19186992.0
# Albania         131185.0      2396.0  1.607552e+07      307985.0
# Algeria         122311.0      3261.0  2.417390e+07      740111.0
# Andorra          13232.0       125.0  2.001700e+06       28544.0
# ...                  ...         ...           ...           ...
# Vietnam           2942.0        35.0  4.937140e+05        9143.0
# World        151372377.0   3192566.0  2.170926e+10   529642430.0
# Yemen             6325.0      1229.0  7.786870e+05      201614.0
# Zambia           91670.0      1251.0  1.089980e+07      170641.0
# Zimbabwe         38260.0      1568.0  5.404837e+06      192947.0
#
#              weekly_cases  weekly_deaths  biweekly_cases  biweekly_deaths
# location
# Afghanistan  4.157080e+05        18257.0    8.232170e+05          36146.0
# ...

# %%
mask = df['location']=='Germany'

# %%
dfg = df[mask]
dfg
# Out:
#              date location  new_cases  new_deaths  total_cases  total_deaths  \
# 28912  2020-01-27  Germany        1.0         NaN          1.0           NaN
# 28913  2020-01-28  Germany        3.0         NaN          4.0           NaN
# 28914  2020-01-29  Germany        0.0         NaN          4.0           NaN
# 28915  2020-01-30  Germany        0.0         NaN          4.0           NaN
# 28916  2020-01-31  Germany        1.0         NaN          5.0           NaN
# ...           ...      ...        ...         ...          ...           ...
# 29368  2021-04-27  Germany    25911.0       316.0    3338564.0       82325.0
# 29369  2021-04-28  Germany    28263.0       263.0    3366827.0       82588.0
# 29370  2021-04-29  Germany    24212.0       277.0    3391039.0       82865.0
# 29371  2021-04-30  Germany    14326.0       232.0    3405365.0       83097.0
# 29372  2021-05-01  Germany    18535.0       110.0    3423900.0       83207.0
#
# ...

# %%
dfg['total_cases'].value_counts().plot(kind='bar', figsize=(8,8))
# Out:
# <AxesSubplot:>
